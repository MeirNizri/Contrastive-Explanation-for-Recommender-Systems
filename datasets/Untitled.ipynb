# %%
import pandas as pd

# %%
ratings = pd.read_csv('cellphones ratings.csv')
cellphones = pd.read_csv('cellphones data.csv')

# %%
df = ratings.merge(cellphones, how='inner', on='cellphone_id').sort_values(by='user_id', ascending=False)
df.loc[df['user_id'] == 16]
# Out:
#      user_id  cellphone_id  rating     brand                 model  \
# 148       16            10       7   Samsung            Galaxy S22
# 845       16            20       5   OnePlus                10 Pro
# 816       16            30       3  Motorola    Moto G Play (2021)
# 60        16             7       8   Samsung            Galaxy A13
# 666       16            29       5  Motorola  Moto G Stylus (2022)
# 36        16             3       3     Apple         iPhone 13 Pro
# 210       16             9       4   Samsung            Galaxy A53
# 730       16            16       7    Google              Pixel 6a
# 510       16             2       7     Apple             iPhone 13
# 350       16             4       8     Apple     iPhone 13 Pro Max
#
#     operating system  internal memory  RAM  performance  main camera  \
# 148          Android              128    8         8.81           50
# 845          Android              128    8         8.86           48
# ...
